# %%
from dolo import *

# %%
model_dolo = yaml_import("simple.yaml")
print( model_dolo )
# Out:
#         Model:
#         ------
#         name: "None"
#         type: "dtcc"
#         file: "<string>
#
# Equations:
# ----------
#
# transition
#  1  : 0.1340 : m[t] = (m[t-1] - (c[t-1]))*(R) + (Γ)*(p[t-1])
#  2  : 0.0300 : p[t] = (Γ)*(p[t-1])
#
# arbitrage
#  1  : -1.0667 : (β)*(((c[t+1])^(1 - (ρ)))/(1 - (ρ)))
#
# definitions

# %%
dr = time_iteration(model_dolo, maxit = 5, verbose=True)
dr = improved_time_iteration(model_dolo, tol=1e-08, dr0=dr, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-8141dd7cb10f> in <module>
# ----> 1 dr = time_iteration(model_dolo, maxit = 5, verbose=True)
#       2 dr = improved_time_iteration(model_dolo, tol=1e-08, dr0=dr, verbose=True)
#
# ~/.cache/pypoetry/virtualenvs/darkolo-8W5AMeku-py3.7/lib/python3.7/site-packages/dolo/algos/time_iteration.py in time_iteration(model, dr0, with_complementarities, dprocess, verbose, maxit, inner_maxit, tol, hook, details, interp_method)
#      89         grid = ProductGrid(dprocess.grid, endo_grid, names=["exo", "endo"])
#      90     else:
# ---> 91         grid, dprocess = model.discretize()
#      92
#      93     n_ms = dprocess.n_nodes  # number of exogenous states
#
# ~/.cache/pypoetry/virtualenvs/darkolo-8W5AMeku-py3.7/lib/python3.7/site-packages/dolo/compiler/model.py in discretize(self, grid_options, dprocess_options)
#     583
#     584     def discretize(self, grid_options={}, dprocess_options={}):
# --> 585         dprocess = self.exogenous.discretize(**dprocess_options)
#     586         endo_grid = self.domain.discretize(**grid_options)
#     587         from dolo.numeric.grids import ProductGrid
#
# AttributeError: 'dict' object has no attribute 'discretize'
