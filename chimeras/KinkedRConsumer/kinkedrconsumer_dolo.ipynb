# %%
from dolo import *

# %%
model_dolo = yaml_import("kinkedrconsumer.yaml")
print(model_dolo)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-2-51abe45d7082> in <module>
# ----> 1 model_dolo = yaml_import("kinkedrconsumer.yaml")
#       2 print(model_dolo)
#
# ~/.cache/pypoetry/virtualenvs/darkolo-8W5AMeku-py3.7/lib/python3.7/site-packages/dolo/compiler/model_import.py in yaml_import(fname, check, check_only)
#      34     from dolo.compiler.model import Model
#      35
# ---> 36     return Model(data, check=check)
#      37     # from dolo.compiler.model import SymbolicModel
#
# ~/.cache/pypoetry/virtualenvs/darkolo-8W5AMeku-py3.7/lib/python3.7/site-packages/dolo/compiler/model.py in __init__(self, data, check, compat)
#     539             self.definitions
#     540             self.calibration
# --> 541             self.domain
#     542             self.exogenous
#     543             self.x_bounds
#
# ...
